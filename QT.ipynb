# %%
import pandas as pd
import numpy as np

# %%
tt = pd.read_csv('keto-micros.csv', header=None, sep='\t')

# %%
tt
# Out:
#                 0       1         2       3        4      5      6      7   \
# 0       Ingredient  Metric  Quantity    Kcal  Protein  Carbs    Fat  Fiber
# 1              Egg     ind         1      71      6.3    0.4    5.0    0.0
# 2         Broccoli      gr       100    35.0      2.4    7.2    0.4    3.3
# 3        Mushrooms      gr       100    28.0      2.2    5.3    0.5    2.2
# 4            Onion      gr       100    42.0      1.4    9.6    0.2    1.4
# 5          Almonds      gr       100     575     21.2   21.7   49.4   12.2
# 6           Pecans      gr       100     691      9.2     14     72    9.6
# 7          Cashews      gr       100     553       18     30     44    3.3
# 8              Oil     ind         1  134.85      0.0    0.0   15.0    0.0
# 9      Blueberries      gr       100    57.0      0.7   14.0    0.3    2.4
# 10   ChickenBreast      gr       100   165.0     31.0    0.0    3.6    0.0
# ...
