# %%
import pandas as pd
import numpy as np

# %%
tt = pd.read_csv('keto-micros.csv', header=None, sep='\t')
# Out:
# --------------------------------------------------------------------------
# ParserError                              Traceback (most recent call last)
# <ipython-input-4-0e5c37d74369> in <module>()
# ----> 1 tt = pd.read_csv('keto-micros.csv', header=None, sep='\t')
#
# ...

# %%
tt
# Out:
#                                             0    1      2       3      4  \
# 0                                         Egg  ind    1.0   78.00   6.00
# 1                                    EggWhite  ind    1.0   17.00   3.80
# 2                                    Broccoli   gr  100.0   34.00   2.80
# 3                                   Mushrooms   gr  100.0   22.00   3.10
# 4                                       Onion  ind    1.0   60.00   1.70
# 5                              CherryTomatoes   gr  150.0   25.00   1.00
# 6                                     SoyMilk   gr  100.0   39.00   3.00
# 7                                     Almonds  ind    1.0    7.00   0.30
# 8                                      Pecans  ind    1.0   10.00   0.13
# 9                                         Oil  ind    1.0  134.85   0.00
# 10                                Blueberries   gr  100.0   57.00   0.70
# 11                               Blackberries   gr  100.0   43.00   1.00
# ...
